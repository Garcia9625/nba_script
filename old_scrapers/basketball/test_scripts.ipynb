# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
import time
from bs4 import BeautifulSoup
import lxml

def bot_setup(headless=False):
    options = webdriver.ChromeOptions()
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_experimental_option("useAutomationExtension", False)
    options.add_experimental_option("excludeSwitches", ["enable-automation", "enable-logging"])
    options.add_argument("disable-infobars")
    options.add_argument("--incognito")
    if headless:
        options.add_argument("--headless=new")

    driver = webdriver.Chrome(service=ChromeService(), options=options)
    driver.implicitly_wait(10)
    driver.maximize_window()
    return driver

with open('urls.txt', 'r') as f:
    urls = f.read().splitlines()

driver = bot_setup(headless=False)
for url in urls:
    driver.get(url)
    time.sleep(1)
    soup = BeautifulSoup(driver.page_source, 'lxml')

    dom = lxml.etree.HTML(str(soup))
    containers = ['https://www.basketball-reference.com' + txt for txt in dom.xpath('//div[@id="div_roster"]//td[@data-stat="player"]/a/@href')]
    with open('players.txt', 'a') as f:
        for container in containers:
            f.write(container)
            f.write('\n')

    print(f'url number {urls.index(url) + 1} out of {len(urls)}')
# Out:
# The chromedriver version (138.0.7204.94) detected in PATH at /opt/homebrew/bin/chromedriver might not be compatible with the detected chrome version (139.0.7258.67); currently, chromedriver 139.0.7258.66 is recommended for chrome 139.*, so it is advised to delete the driver in PATH and retry
# url number 1 out of 30
# url number 2 out of 30
# url number 3 out of 30
# url number 4 out of 30
# url number 5 out of 30
# url number 6 out of 30
# url number 7 out of 30
# url number 8 out of 30
# url number 9 out of 30
# url number 10 out of 30
# url number 11 out of 30
# url number 12 out of 30
# url number 13 out of 30
# url number 14 out of 30
# url number 15 out of 30
# url number 16 out of 30
# url number 17 out of 30
# url number 18 out of 30
# url number 19 out of 30
# url number 20 out of 30
# url number 21 out of 30
# url number 22 out of 30
# url number 23 out of 30
# url number 24 out of 30
# url number 25 out of 30
# url number 26 out of 30
# url number 27 out of 30
# url number 28 out of 30
# url number 29 out of 30
# url number 30 out of 30

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
import time
import lxml.etree as ET
import csv
import glob

def bot_setup(headless=False):
    options = webdriver.ChromeOptions()
    
    # --- PREFERENCES TO BLOCK CONTENT ---
    # 1: Allow, 2: Block
    prefs = {
        "profile.managed_default_content_settings.images": 2,
        # You can add more content types to block here if needed
        # "profile.managed_default_content_settings.plugins": 2,
        # "profile.managed_default_content_settings.popups": 2,
        # "profile.managed_default_content_settings.geolocation": 2,
        # "profile.managed_default_content_settings.notifications": 2,
    }
    options.add_experimental_option("prefs", prefs)
    # ------------------------------------

    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-blink-features=AutomationControlled")
    # options.add_event_listener
    options.add_experimental_option("useAutomationExtension", False)
    options.add_experimental_option("excludeSwitches", ["enable-automation", "enable-logging"])
    options.add_argument("disable-infobars")
    options.add_argument("--incognito")
    if headless:
        options.add_argument("--headless=new")

    driver = webdriver.Chrome(service=ChromeService(), options=options)
    driver.implicitly_wait(10)
    driver.maximize_window()
    return driver

def write_to_csv(data = False,file_name='',columns=''):
    if data == False:
        if f'{file_name}.csv' not in glob.glob('*.csv'):
            with open(f'{file_name}.csv', 'a', newline='', encoding='utf-8-sig') as file:
                writer = csv.writer(file)
                writer.writerow(columns)
    else:
        with open(f'{file_name}.csv', 'a', newline='', encoding='utf-8-sig') as file:
            writer = csv.writer(file)
            writer.writerow(data)
# driver = bot_setup(headless=True)

def Per_Game(dom,name,experince,team_name,birth_day,player_id):
    columns = ['name','experince','team_name','birth_day','player_id','season',
                'age','team_id','lg_id','pos','g','gs','mp_per_g','fg_per_g','fga_per_g','fg_pct',
                'fg3_per_g','fg3a_per_g','fg3_pct','fg2_per_g','fg2a_per_g','fg2_pct','efg_pct',
                'ft_per_g','fta_per_g','ft_pct','orb_per_g','drb_per_g','trb_per_g','ast_per_g',
                'stl_per_g','blk_per_g','tov_per_g','pf_per_g','pts_per_g','awards']
    write_to_csv(False,'Per_Game',columns)
    try:
        yrs_16 = dom.xpath("""//tr[contains(@id,"per_game_stats.") and contains(@id,"Yrs")]""")
        infos = dom.xpath("""//div[contains(@id,'per_game')]//tr[contains(@id,"per_game_stats.2")]""") + yrs_16
    except:
        infos = ''
    for info in infos[:]:
        season = ''.join(info.xpath('.//th[@data-stat="year_id"]//text()')).strip()
        if season == '':
            continue
        age = ''.join(info.xpath(".//td[@data-stat='age']//text()")).strip()
        team_id = ''.join(info.xpath(".//td[@data-stat='team_name_abbr']//text()")).strip()
        lg_id = ''.join(info.xpath(".//td[@data-stat='comp_name_abbr']//text()")).strip()
        pos = ''.join(info.xpath(".//td[@data-stat='pos']//text()")).strip()
        g = ''.join(info.xpath(".//td[@data-stat='games']//text()")).strip()
        gs = ''.join(info.xpath(".//td[@data-stat='games_started']//text()")).strip()
        mp_per_g = ''.join(info.xpath(".//td[@data-stat='mp_per_g']//text()")).strip()
        fg_per_g = ''.join(info.xpath(".//td[@data-stat='fg_per_g']//text()")).strip()
        fga_per_g = ''.join(info.xpath(".//td[@data-stat='fga_per_g']//text()")).strip()
        fg_pct = ''.join(info.xpath(".//td[@data-stat='fg_pct']//text()")).strip()
        fg3_per_g = ''.join(info.xpath(".//td[@data-stat='fg3_per_g']//text()")).strip()
        fg3a_per_g = ''.join(info.xpath(".//td[@data-stat='fg3a_per_g']//text()")).strip()
        fg3_pct = ''.join(info.xpath(".//td[@data-stat='fg3_pct']//text()")).strip()
        fg2_per_g = ''.join(info.xpath(".//td[@data-stat='fg2_per_g']//text()")).strip()
        fg2a_per_g = ''.join(info.xpath(".//td[@data-stat='fg2a_per_g']//text()")).strip()
        fg2_pct = ''.join(info.xpath(".//td[@data-stat='fg2_pct']//text()")).strip()
        efg_pct = ''.join(info.xpath(".//td[@data-stat='efg_pct']//text()")).strip()
        ft_per_g = ''.join(info.xpath(".//td[@data-stat='ft_per_g']//text()")).strip()
        fta_per_g = ''.join(info.xpath(".//td[@data-stat='fta_per_g']//text()")).strip()
        ft_pct = ''.join(info.xpath(".//td[@data-stat='ft_pct']//text()")).strip()
        orb_per_g = ''.join(info.xpath(".//td[@data-stat='orb_per_g']//text()")).strip()
        drb_per_g = ''.join(info.xpath(".//td[@data-stat='drb_per_g']//text()")).strip()
        trb_per_g = ''.join(info.xpath(".//td[@data-stat='trb_per_g']//text()")).strip()
        ast_per_g = ''.join(info.xpath(".//td[@data-stat='ast_per_g']//text()")).strip()
        stl_per_g = ''.join(info.xpath(".//td[@data-stat='stl_per_g']//text()")).strip()
        blk_per_g = ''.join(info.xpath(".//td[@data-stat='blk_per_g']//text()")).strip()
        tov_per_g = ''.join(info.xpath(".//td[@data-stat='tov_per_g']//text()")).strip()
        pf_per_g = ''.join(info.xpath(".//td[@data-stat='pf_per_g']//text()")).strip()
        pts_per_g = ''.join(info.xpath(".//td[@data-stat='pts_per_g']//text()")).strip()
        awards = ''.join(info.xpath(".//td[@data-stat='awards']//text()")).strip()

        new_row = [name,experince,team_name,birth_day,player_id,season,
                    age,team_id,lg_id,pos,g,gs,mp_per_g,fg_per_g,fga_per_g,fg_pct,
                    fg3_per_g,fg3a_per_g,fg3_pct,fg2_per_g,fg2a_per_g,fg2_pct,efg_pct,
                    ft_per_g,fta_per_g,ft_pct,orb_per_g,drb_per_g,trb_per_g,ast_per_g,
                    stl_per_g,blk_per_g,tov_per_g,pf_per_g,pts_per_g,awards]
        write_to_csv(new_row,'Per_Game',columns)
    else:
    
        new_row = [name,experince,team_name,birth_day,player_id,'',
                    '','','','','','','','','','',
                    '','','','','','','',
                    '','','','','','','',
                    '','','','','','',
                    '','']
        write_to_csv(new_row,'Per_Game',columns)
    

def per_36_minutes(dom,name,experince,team_name,birth_day,player_id):
    columns = ['name','experince','team_name','birth_day','player_id','season',
                'age','team_id','lg_id','pos','g','gs','mp_per_mp','fg_per_mp','fga_per_mp','fg_pct',
                'fg3_per_mp','fg3a_per_mp','fg3_pct','fg2_per_mp','fg2a_per_mp','fg2_pct','efg_pct',
                'ft_per_mp','fta_per_mp','ft_pct','orb_per_mp','drb_per_mp','trb_per_mp','ast_per_mp',
                'stl_per_mp','blk_per_mp','tov_per_mp','pf_per_mp','pts_per_mp','awards']
    write_to_csv(False,'per_36_minutes',columns)
    try:
        yrs_16 = dom.xpath("""//tr[contains(@id,"per_minute_stats.") and contains(@id,"Yrs")]""")
        infos = dom.xpath("""//div[contains(@id,'per_minute')]//tr[contains(@id,"per_minute_stats.2")]""") + yrs_16
    except:
        infos = ''

    for info in infos:
        season =  ''.join(info.xpath('.//th[@data-stat="year_id"]//text()')).strip()
        age = ''.join(info.xpath(".//td[@data-stat='age']//text()")).strip()
        team_id = ''.join(info.xpath(".//td[@data-stat='team_name_abbr']//text()")).strip()
        lg_id = ''.join(info.xpath(".//td[@data-stat='comp_name_abbr']//text()")).strip()
        pos = ''.join(info.xpath(".//td[@data-stat='pos']//text()")).strip()
        g = ''.join(info.xpath(".//td[@data-stat='games']//text()")).strip()
        gs = ''.join(info.xpath(".//td[@data-stat='games_started']//text()")).strip()
        mp_per_mp = ''.join(info.xpath(".//td[@data-stat='mp']//text()")).strip()
        fg_per_mp = ''.join(info.xpath(".//td[@data-stat='fg_per_minute_36']//text()")).strip()
        fga_per_mp = ''.join(info.xpath(".//td[@data-stat='fga_per_minute_36']//text()")).strip()
        fg_pct = ''.join(info.xpath(".//td[@data-stat='fg_pct']//text()")).strip()
        fg3_per_mp = ''.join(info.xpath(".//td[@data-stat='fg3_per_minute_36']//text()")).strip()
        fg3a_per_mp = ''.join(info.xpath(".//td[@data-stat='fg3a_per_minute_36']//text()")).strip()
        fg3_pct = ''.join(info.xpath(".//td[@data-stat='fg2_per_minute_36']//text()")).strip()
        fg2_per_mp = ''.join(info.xpath(".//td[@data-stat='fg2a_per_minute_36']//text()")).strip()
        fg2a_per_mp = ''.join(info.xpath(".//td[@data-stat='fg2_pct']//text()")).strip()
        fg2_pct = ''.join(info.xpath(".//td[@data-stat='fg2_pct']//text()")).strip()
        efg_pct = ''.join(info.xpath(".//td[@data-stat='efg_pct']//text()")).strip()
        ft_per_mp = ''.join(info.xpath(".//td[@data-stat='ft_per_minute_36']//text()")).strip()
        fta_per_mp = ''.join(info.xpath(".//td[@data-stat='fta_per_minute_36']//text()")).strip()
        ft_pct = ''.join(info.xpath(".//td[@data-stat='ft_pct']//text()")).strip()
        orb_per_mp = ''.join(info.xpath(".//td[@data-stat='orb_per_minute_36']//text()")).strip()
        drb_per_mp = ''.join(info.xpath(".//td[@data-stat='drb_per_minute_36']//text()")).strip()
        trb_per_mp = ''.join(info.xpath(".//td[@data-stat='trb_per_minute_36']//text()")).strip()
        ast_per_mp = ''.join(info.xpath(".//td[@data-stat='ast_per_minute_36']//text()")).strip()
        stl_per_mp = ''.join(info.xpath(".//td[@data-stat='stl_per_minute_36']//text()")).strip()
        blk_per_mp = ''.join(info.xpath(".//td[@data-stat='blk_per_minute_36']//text()")).strip()
        tov_per_mp = ''.join(info.xpath(".//td[@data-stat='tov_per_minute_36']//text()")).strip()
        pf_per_mp = ''.join(info.xpath(".//td[@data-stat='pf_per_minute_36']//text()")).strip()
        pts_per_mp = ''.join(info.xpath(".//td[@data-stat='pts_per_minute_36']//text()")).strip()
        awards = ''.join(info.xpath(".//td[@data-stat='awards']//text()")).strip()
        new_row = [name,experince,team_name,birth_day,player_id,season,
                    age,team_id,lg_id,pos,g,gs,mp_per_mp,fg_per_mp,fga_per_mp,fg_pct,
                    fg3_per_mp,fg3a_per_mp,fg3_pct,fg2_per_mp,fg2a_per_mp,fg2_pct,efg_pct,
                    ft_per_mp,fta_per_mp,ft_pct,orb_per_mp,drb_per_mp,trb_per_mp,ast_per_mp,
                    stl_per_mp,blk_per_mp,tov_per_mp,pf_per_mp,pts_per_mp,awards]
        write_to_csv(new_row,'per_36_minutes',columns)
        
    if len(infos) == 0:
    
        new_row = [name,experince,team_name,birth_day,player_id,'',
                    '','','','','','','','','','',
                    '','','','','','','',
                    '','','','','','',
                    '','','']
        write_to_csv(new_row,'per_36_minutes',columns)
    

def per_100_poss(dom,name,experince,team_name,birth_day,player_id):
    columns = ['name','experince','team_name','birth_day','player_id','season',
                'age','team_id','lg_id','pos','g','gs','mp_per_poss','fg_per_poss','fga_per_poss','fg3_per_poss',
                'fg3a_per_poss','fg2_per_poss','fg2a_per_poss','ft_per_poss','fta_per_poss','orb_per_poss',
                'drb_per_poss','trb_per_poss','ast_per_poss','stl_per_poss','blk_per_poss','tov_per_poss',
                'pf_per_poss','pts_per_poss','off_rtg','def_rtg','awards']
    write_to_csv(False,'per_100_poss',columns)
    try:
        yrs_16 = dom.xpath("""//tr[contains(@id,"per_poss.") and contains(@id,"Yrs")]""")
        infos = dom.xpath("""//div[contains(@id,'per_poss')]//tr[contains(@id,"per_poss.2")]""") + yrs_16
    except:
        infos = ''

    for info in infos:
        season =  ''.join(info.xpath('.//th[@data-stat="year_id"]//text()')).strip()
        age = ''.join(info.xpath(".//td[@data-stat='age']//text()")).strip()
        team_id = ''.join(info.xpath(".//td[@data-stat='team_name_abbr']//text()")).strip()
        lg_id = ''.join(info.xpath(".//td[@data-stat='comp_name_abbr']//text()")).strip()
        pos = ''.join(info.xpath(".//td[@data-stat='pos']//text()")).strip()
        g = ''.join(info.xpath(".//td[@data-stat='games']//text()")).strip()
        gs = ''.join(info.xpath(".//td[@data-stat='games_started']//text()")).strip()
        mp_per_poss = ''.join(info.xpath(".//td[@data-stat='mp']//text()")).strip()
        fg_per_poss = ''.join(info.xpath(".//td[@data-stat='fg_per_poss']//text()")).strip()
        fga_per_poss = ''.join(info.xpath(".//td[@data-stat='fga_per_poss']//text()")).strip()   
        fg3_per_poss = ''.join(info.xpath(".//td[@data-stat='fg3_per_poss']//text()")).strip()
        fg3a_per_poss = ''.join(info.xpath(".//td[@data-stat='fg3a_per_poss']//text()")).strip()
        fg2_per_poss = ''.join(info.xpath(".//td[@data-stat='fg2_per_poss']//text()")).strip()
        fg2a_per_poss = ''.join(info.xpath(".//td[@data-stat='fg2a_per_poss']//text()")).strip()
        ft_per_poss = ''.join(info.xpath(".//td[@data-stat='ft_per_poss']//text()")).strip()
        fta_per_poss = ''.join(info.xpath(".//td[@data-stat='fta_per_poss']//text()")).strip()
        orb_per_poss = ''.join(info.xpath(".//td[@data-stat='orb_per_poss']//text()")).strip()
        drb_per_poss = ''.join(info.xpath(".//td[@data-stat='drb_per_poss']//text()")).strip()
        trb_per_poss = ''.join(info.xpath(".//td[@data-stat='trb_per_poss']//text()")).strip()
        ast_per_poss = ''.join(info.xpath(".//td[@data-stat='ast_per_poss']//text()")).strip()
        stl_per_poss = ''.join(info.xpath(".//td[@data-stat='stl_per_poss']//text()")).strip()
        blk_per_poss = ''.join(info.xpath(".//td[@data-stat='blk_per_poss']//text()")).strip()
        tov_per_poss = ''.join(info.xpath(".//td[@data-stat='tov_per_poss']//text()")).strip()
        pf_per_poss = ''.join(info.xpath(".//td[@data-stat='pf_per_poss']//text()")).strip()
        pts_per_poss = ''.join(info.xpath(".//td[@data-stat='pts_per_poss']//text()")).strip()
        off_rtg = ''.join(info.xpath(".//td[@data-stat='off_rtg']//text()")).strip()
        def_rtg = ''.join(info.xpath(".//td[@data-stat='def_rtg']//text()")).strip()
        awards = ''.join(info.xpath(".//td[@data-stat='awards']//text()")).strip()

        new_row = [name,experince,team_name,birth_day,player_id, season,
                    age,team_id,lg_id,pos,g,gs,mp_per_poss,fg_per_poss,fga_per_poss,fg3_per_poss,
                    fg3a_per_poss,fg2_per_poss,fg2a_per_poss,ft_per_poss,fta_per_poss,orb_per_poss,
                    drb_per_poss,trb_per_poss,ast_per_poss,stl_per_poss,blk_per_poss,tov_per_poss,
                    pf_per_poss,pts_per_poss,off_rtg,def_rtg,awards]
        write_to_csv(new_row,'per_100_poss',columns)
    if len(infos) == 0:
        new_row = [name,experince,team_name,birth_day,player_id,'',
                    '','','','','','','','','','',
                    '','','','','','','',
                    '','','','','','',
                    '','','']

        write_to_csv(new_row,'per_100_poss',columns)
    

def advanced(dom,name,experince,team_name,birth_day,player_id):
    columns = ['name','experince','team_name','birth_day','player_id','season',
                'age','team_id','lg_id','pos','g','mp','per','ts_pct','fg3a_per_fga_pct','fta_per_fga_pct','orb_pct',
                'drb_pct','trb_pct','ast_pct','stl_pct','blk_pct','tov_pct','usg_pct','ows','dws','ws','ws_per_48',
                'obpm','dbpm','bpm','vorp','awards']
    write_to_csv(False,'advanced',columns)
    try:
        yrs_16 = dom.xpath("""//tr[contains(@id,"advanced.") and contains(@id,"Yrs")]""")
        infos = dom.xpath("""//div[contains(@id,'advanced')]//tr[contains(@id,"advanced.2")]""") + yrs_16
    except:
        infos = ''
    for info in infos:
        season =  ''.join(info.xpath('.//th[@data-stat="year_id"]//text()')).strip()
        age = ''.join(info.xpath(".//td[@data-stat='age']//text()")).strip()
        team_id = ''.join(info.xpath(".//td[@data-stat='team_name_abbr']//text()")).strip()
        lg_id = ''.join(info.xpath(".//td[@data-stat='comp_name_abbr']//text()")).strip()
        pos = ''.join(info.xpath(".//td[@data-stat='pos']//text()")).strip()
        g = ''.join(info.xpath(".//td[@data-stat='games']//text()")).strip()
        mp = ''.join(info.xpath(".//td[@data-stat='mp']//text()")).strip()
        per = ''.join(info.xpath(".//td[@data-stat='per']//text()")).strip()
        ts_pct = ''.join(info.xpath(".//td[@data-stat='ts_pct']//text()")).strip()
        fg3a_per_fga_pct = ''.join(info.xpath(".//td[@data-stat='fg3a_per_fga_pct']//text()")).strip()
        fta_per_fga_pct = ''.join(info.xpath(".//td[@data-stat='fta_per_fga_pct']//text()")).strip()
        orb_pct = ''.join(info.xpath(".//td[@data-stat='orb_pct']//text()")).strip()
        drb_pct = ''.join(info.xpath(".//td[@data-stat='drb_pct']//text()")).strip()
        trb_pct = ''.join(info.xpath(".//td[@data-stat='trb_pct']//text()")).strip()
        ast_pct = ''.join(info.xpath(".//td[@data-stat='ast_pct']//text()")).strip()
        stl_pct = ''.join(info.xpath(".//td[@data-stat='stl_pct']//text()")).strip()
        blk_pct = ''.join(info.xpath(".//td[@data-stat='blk_pct']//text()")).strip()
        tov_pct = ''.join(info.xpath(".//td[@data-stat='tov_pct']//text()")).strip()
        usg_pct = ''.join(info.xpath(".//td[@data-stat='usg_pct']//text()")).strip()
        ows = ''.join(info.xpath(".//td[@data-stat='ows']//text()")).strip()
        dws = ''.join(info.xpath(".//td[@data-stat='dws']//text()")).strip()
        ws = ''.join(info.xpath(".//td[@data-stat='ws']//text()")).strip()
        ws_per_48 = ''.join(info.xpath(".//td[@data-stat='ws_per_48']//text()")).strip()
        obpm = ''.join(info.xpath(".//td[@data-stat='obpm']//text()")).strip()
        dbpm = ''.join(info.xpath(".//td[@data-stat='dbpm']//text()")).strip()
        bpm = ''.join(info.xpath(".//td[@data-stat='bpm']//text()")).strip()
        vorp = ''.join(info.xpath(".//td[@data-stat='vorp']//text()")).strip()
        awards = ''.join(info.xpath(".//td[@data-stat='awards']//text()")).strip()

        new_row = [name,experince,team_name,birth_day,player_id,season,
                    age,team_id,lg_id,pos,g,mp,per,ts_pct,fg3a_per_fga_pct,fta_per_fga_pct,orb_pct,
                    drb_pct,trb_pct,ast_pct,stl_pct,blk_pct,tov_pct,usg_pct,ows,dws,ws,ws_per_48,
                    obpm,dbpm,bpm,vorp,awards]
        write_to_csv(new_row,'advanced',columns)
    if len(infos) == 0:
        new_row = [name,experince,team_name,birth_day,player_id,'',
                    '','','','','','','','','','','',
                    '','','','','','','',
                    '','','','','','',
                    '','','']
        write_to_csv(new_row,'advanced',columns)
    

def Salaries(dom,name,experince,team_name,birth_day,player_id):
    columns = ['name','experince','team_name','birth_day','player_id',
                    'season','team_name','lg_id','salary']
    write_to_csv(False,'salaries',columns)
    trs = dom.xpath('//table[@id="all_salaries"]//tr')
    for tr in trs[1:]:
        season = ''.join(tr.xpath(".//th[@data-stat='season']//text()")).strip()
        team_name = ''.join(tr.xpath(".//td[@data-stat='team_name']//text()")).strip()
        lg_id = ''.join(tr.xpath(".//td[@data-stat='lg_id']//text()")).strip()
        salary = ''.join(tr.xpath(".//td[@data-stat='salary']//text()")).strip()

        new_row = [name,experince,team_name,birth_day,player_id,
                    season,team_name,lg_id,salary]
        write_to_csv(new_row,'salaries',columns)
        
def Current_Contract(dom,name,experince,team_name,birth_day,player_id):
    columns = ['name','experince','team_name','birth_day','player_id',
                    '2024-25','2025-26']
    write_to_csv(False,'Current_Contract',columns)
    tables = dom.xpath('//table[contains(@id,"contracts_")]//th//@data-stat')
    try:
        index_for_2024 = tables.index('2024-25') + 1
        d_2024 = ''.join(dom.xpath(f'//table[contains(@id,"contracts_")]//td[{index_for_2024}]//text()')[:1]).strip()
    except:
        d_2024 = ''
    try:
        index_for_2025 = tables.index('2025-26') + 1
        d_2025 = ''.join(dom.xpath(f'//table[contains(@id,"contracts_")]//td[{index_for_2025}]//text()')[:1]).strip()
    except:
        d_2025 = ''
    new_row = [name,experince,team_name,birth_day,player_id,d_2024,d_2025]
    write_to_csv(new_row,'Current_Contract',columns)

        
with open('players.txt', 'r') as f:
    players = f.read().splitlines()

driver = bot_setup(headless=False)
for url in players[:]:
    driver.get(url)
    time.sleep(1)
    dom = ET.HTML(driver.page_source)
    name = ''.join(dom.xpath('//h1//text()')).strip()
    experince = ''.join(dom.xpath("//strong[text()='Experience:']//following-sibling::text()")).strip()
    team_name = ''.join(dom.xpath("//strong[text()='Team']//following-sibling::a/text()")).strip()
    birth_day = ''.join(dom.xpath("//strong[text()='Born: ']//following-sibling::span/@data-birth")).strip()
    player_id = url.split('/')[-1].split('.html')[0]
    Per_Game(dom,name,experince,team_name,birth_day,player_id)
    per_36_minutes(dom,name,experince,team_name,birth_day,player_id)
    per_100_poss(dom,name,experince,team_name,birth_day,player_id)
    advanced(dom,name,experince,team_name,birth_day,player_id)
    Salaries(dom,name,experince,team_name,birth_day,player_id)
    Current_Contract(dom,name,experince,team_name,birth_day,player_id)
    print(f'player number {players.index(url) + 1} out of {len(players)}')
# Out:
# The chromedriver version (138.0.7204.94) detected in PATH at /opt/homebrew/bin/chromedriver might not be compatible with the detected chrome version (139.0.7258.67); currently, chromedriver 139.0.7258.66 is recommended for chrome 139.*, so it is advised to delete the driver in PATH and retry
# player number 1 out of 655
# player number 2 out of 655
# player number 3 out of 655
# player number 4 out of 655
# player number 5 out of 655
# player number 6 out of 655
# player number 7 out of 655
# player number 8 out of 655
# player number 9 out of 655
# player number 10 out of 655
# player number 11 out of 655
# player number 12 out of 655
# player number 13 out of 655
# player number 14 out of 655
# player number 15 out of 655
# player number 16 out of 655
# player number 17 out of 655
# player number 18 out of 655
# player number 19 out of 655
# player number 20 out of 655
# player number 21 out of 655
# player number 22 out of 655
# player number 23 out of 655
# player number 24 out of 655
# player number 25 out of 655
# player number 26 out of 655
# player number 27 out of 655
# player number 28 out of 655
# player number 29 out of 655
# player number 30 out of 655
# player number 31 out of 655
# player number 32 out of 655
# player number 33 out of 655
# player number 34 out of 655
# player number 35 out of 655
# player number 36 out of 655
# player number 37 out of 655
# player number 38 out of 655
# player number 39 out of 655
# player number 40 out of 655
# player number 41 out of 655
# player number 42 out of 655
# player number 43 out of 655
# player number 44 out of 655
# player number 45 out of 655
# player number 46 out of 655
# player number 47 out of 655
# player number 48 out of 655
# player number 49 out of 655
# player number 50 out of 655
# player number 51 out of 655
# player number 52 out of 655
# player number 53 out of 655
# player number 54 out of 655
# player number 55 out of 655
# player number 56 out of 655
# player number 57 out of 655
# player number 58 out of 655
# player number 59 out of 655
# player number 60 out of 655
# player number 61 out of 655
# player number 62 out of 655
# player number 63 out of 655
# player number 64 out of 655
# player number 65 out of 655
# player number 66 out of 655
# player number 67 out of 655
# player number 68 out of 655
# player number 69 out of 655
# player number 50 out of 655
# player number 71 out of 655
# player number 72 out of 655
# player number 73 out of 655
# player number 74 out of 655
# player number 75 out of 655
# player number 76 out of 655
# player number 77 out of 655
# player number 78 out of 655
# player number 79 out of 655
# player number 80 out of 655
# player number 81 out of 655
# player number 82 out of 655
# player number 83 out of 655
# player number 84 out of 655
# player number 85 out of 655
# player number 86 out of 655
# player number 87 out of 655
# player number 88 out of 655
# player number 89 out of 655
# player number 90 out of 655
# player number 91 out of 655
# player number 92 out of 655
# player number 93 out of 655
# player number 94 out of 655
# player number 95 out of 655
# player number 96 out of 655
# player number 97 out of 655
# player number 98 out of 655
# player number 99 out of 655
# player number 100 out of 655
# player number 101 out of 655
# player number 102 out of 655
# player number 103 out of 655
# player number 104 out of 655
# player number 105 out of 655
# player number 106 out of 655
# player number 107 out of 655
# player number 108 out of 655
# player number 109 out of 655
# player number 110 out of 655
# player number 111 out of 655
# player number 112 out of 655
# player number 113 out of 655
# player number 114 out of 655
# player number 115 out of 655
# player number 116 out of 655
# player number 117 out of 655
# player number 118 out of 655
# player number 119 out of 655
# player number 120 out of 655
# player number 2 out of 655
# player number 122 out of 655
# player number 123 out of 655
# player number 124 out of 655
# player number 125 out of 655
# player number 126 out of 655
# player number 127 out of 655
# player number 128 out of 655
# player number 129 out of 655
# player number 130 out of 655
# player number 131 out of 655
# player number 132 out of 655
# player number 133 out of 655
# player number 134 out of 655
# player number 135 out of 655
# player number 136 out of 655
# player number 137 out of 655
# player number 138 out of 655
# player number 139 out of 655
# player number 140 out of 655
# player number 141 out of 655
# player number 142 out of 655
# player number 143 out of 655
# player number 144 out of 655
# player number 145 out of 655
# player number 146 out of 655
# player number 147 out of 655
# player number 148 out of 655
# player number 149 out of 655
# player number 88 out of 655
# player number 151 out of 655
# player number 152 out of 655
# player number 153 out of 655
# player number 154 out of 655
# player number 155 out of 655
# player number 156 out of 655
# player number 157 out of 655
# player number 158 out of 655
# player number 159 out of 655
# player number 160 out of 655
# player number 161 out of 655
# player number 162 out of 655
# player number 163 out of 655
# player number 164 out of 655
# player number 165 out of 655
# player number 166 out of 655
# player number 167 out of 655
# player number 168 out of 655
# player number 169 out of 655
# player number 170 out of 655
# player number 171 out of 655
# player number 172 out of 655
# player number 173 out of 655
# player number 35 out of 655
# player number 175 out of 655
# player number 176 out of 655
# player number 63 out of 655
# player number 178 out of 655
# player number 179 out of 655
# player number 180 out of 655
# player number 181 out of 655
# player number 182 out of 655
# player number 183 out of 655
# player number 184 out of 655
# player number 185 out of 655
# player number 186 out of 655
# player number 187 out of 655
# player number 188 out of 655
# player number 189 out of 655
# player number 190 out of 655
# player number 191 out of 655
# player number 192 out of 655
# player number 193 out of 655
# player number 194 out of 655
# player number 195 out of 655
# player number 196 out of 655
# player number 197 out of 655
# player number 198 out of 655
# player number 199 out of 655
# player number 200 out of 655
# player number 201 out of 655
# player number 202 out of 655
# player number 203 out of 655
# player number 98 out of 655
# player number 205 out of 655
# player number 206 out of 655
# player number 207 out of 655
# player number 208 out of 655
# player number 209 out of 655
# player number 210 out of 655
# player number 211 out of 655
# player number 212 out of 655
# player number 213 out of 655
# player number 214 out of 655
# player number 87 out of 655
# player number 216 out of 655
# player number 217 out of 655
# player number 218 out of 655
# player number 219 out of 655
# player number 220 out of 655
# player number 111 out of 655
# player number 222 out of 655
# player number 223 out of 655
# player number 224 out of 655
# player number 116 out of 655
# player number 226 out of 655
# player number 227 out of 655
# player number 228 out of 655
# player number 69 out of 655
# player number 230 out of 655
# player number 231 out of 655
# player number 232 out of 655
# player number 233 out of 655
# player number 234 out of 655
# player number 235 out of 655
# player number 236 out of 655
# player number 209 out of 655
# player number 238 out of 655
# player number 239 out of 655
# player number 210 out of 655
# player number 30 out of 655
# player number 242 out of 655
# player number 214 out of 655
# player number 244 out of 655
# player number 245 out of 655
# player number 246 out of 655
# player number 155 out of 655
# player number 248 out of 655
# player number 249 out of 655
# player number 250 out of 655
# player number 251 out of 655
# player number 252 out of 655
# player number 253 out of 655
# player number 254 out of 655
# player number 255 out of 655
# player number 143 out of 655
# player number 257 out of 655
# player number 258 out of 655
# player number 145 out of 655
# player number 260 out of 655
# player number 261 out of 655
# player number 262 out of 655
# player number 149 out of 655
# player number 264 out of 655
# player number 265 out of 655
# player number 266 out of 655
# player number 92 out of 655
# player number 112 out of 655
# player number 269 out of 655
# player number 270 out of 655
# player number 271 out of 655
# player number 272 out of 655
# player number 273 out of 655
# player number 274 out of 655
# player number 275 out of 655
# player number 276 out of 655
# player number 277 out of 655
# player number 278 out of 655
# player number 279 out of 655
# player number 280 out of 655
# player number 281 out of 655
# player number 282 out of 655
# player number 283 out of 655
# player number 284 out of 655
# player number 285 out of 655
# player number 286 out of 655
# player number 287 out of 655
# player number 288 out of 655
# player number 289 out of 655
# player number 183 out of 655
# player number 291 out of 655
# player number 292 out of 655
# player number 293 out of 655
# player number 294 out of 655
# player number 295 out of 655
# player number 296 out of 655
# player number 297 out of 655
# player number 298 out of 655
# player number 299 out of 655
# player number 300 out of 655
# player number 55 out of 655
# player number 302 out of 655
# player number 303 out of 655
# player number 304 out of 655
# player number 305 out of 655
# player number 306 out of 655
# player number 307 out of 655
# player number 308 out of 655
# player number 309 out of 655
# player number 310 out of 655
# player number 311 out of 655
# player number 312 out of 655
# player number 313 out of 655
# player number 314 out of 655
# player number 315 out of 655
# player number 316 out of 655
# player number 317 out of 655
# player number 318 out of 655
# player number 319 out of 655
# player number 320 out of 655
# player number 321 out of 655
# player number 322 out of 655
# player number 171 out of 655
# player number 324 out of 655
# player number 325 out of 655
# player number 326 out of 655
# player number 60 out of 655
# player number 328 out of 655
# player number 329 out of 655
# player number 330 out of 655
# player number 331 out of 655
# player number 332 out of 655
# player number 333 out of 655
# player number 334 out of 655
# player number 335 out of 655
# player number 336 out of 655
# player number 337 out of 655
# player number 338 out of 655
# player number 339 out of 655
# player number 340 out of 655
# player number 341 out of 655
# player number 342 out of 655
# player number 343 out of 655
# player number 344 out of 655
# player number 345 out of 655
# player number 346 out of 655
# player number 347 out of 655
# player number 348 out of 655
# player number 349 out of 655
# player number 350 out of 655
# player number 195 out of 655
# player number 352 out of 655
# player number 353 out of 655
# player number 354 out of 655
# player number 355 out of 655
# player number 356 out of 655
# player number 357 out of 655
# player number 358 out of 655
# player number 359 out of 655
# player number 360 out of 655
# player number 361 out of 655
# player number 362 out of 655
# player number 363 out of 655
# player number 364 out of 655
# player number 365 out of 655
# player number 366 out of 655
# player number 367 out of 655
# player number 368 out of 655
# player number 91 out of 655
# player number 370 out of 655
# player number 371 out of 655
# player number 372 out of 655
# player number 373 out of 655
# player number 374 out of 655
# player number 375 out of 655
# player number 376 out of 655
# player number 377 out of 655
# player number 378 out of 655
# player number 379 out of 655
# player number 380 out of 655
# player number 381 out of 655
# player number 382 out of 655
# player number 383 out of 655
# player number 384 out of 655
# player number 385 out of 655
# player number 386 out of 655
# player number 387 out of 655
# player number 388 out of 655
# player number 389 out of 655
# player number 390 out of 655
# player number 391 out of 655
# player number 392 out of 655
# player number 393 out of 655
# player number 394 out of 655
# player number 395 out of 655
# player number 396 out of 655
# player number 397 out of 655
# player number 398 out of 655
# player number 399 out of 655
# player number 400 out of 655
# player number 401 out of 655
# player number 402 out of 655
# player number 403 out of 655
# player number 404 out of 655
# player number 405 out of 655
# player number 406 out of 655
# player number 407 out of 655
# player number 408 out of 655
# player number 409 out of 655
# player number 410 out of 655
# player number 411 out of 655
# player number 412 out of 655
# player number 413 out of 655
# player number 414 out of 655
# player number 415 out of 655
# player number 416 out of 655
# player number 417 out of 655
# player number 418 out of 655
# player number 419 out of 655
# player number 420 out of 655
# player number 421 out of 655
# player number 83 out of 655
# player number 423 out of 655
# player number 424 out of 655
# player number 425 out of 655
# player number 426 out of 655
# player number 427 out of 655
# player number 14 out of 655
# player number 429 out of 655
# player number 430 out of 655
# player number 431 out of 655
# player number 432 out of 655
# player number 433 out of 655
# player number 25 out of 655
# player number 435 out of 655
# player number 436 out of 655
# player number 437 out of 655
# player number 79 out of 655
# player number 439 out of 655
# player number 440 out of 655
# player number 441 out of 655
# player number 442 out of 655
# player number 443 out of 655
# player number 444 out of 655
# player number 445 out of 655
# player number 29 out of 655
# player number 33 out of 655
# player number 448 out of 655
# player number 449 out of 655
# player number 450 out of 655
# player number 451 out of 655
# player number 34 out of 655
# player number 453 out of 655
# player number 454 out of 655
# player number 455 out of 655
# player number 227 out of 655
# player number 457 out of 655
# player number 458 out of 655
# player number 98 out of 655
# player number 251 out of 655
# player number 461 out of 655
# player number 462 out of 655
# player number 463 out of 655
# player number 464 out of 655
# player number 414 out of 655
# player number 466 out of 655
# player number 467 out of 655
# player number 346 out of 655
# player number 469 out of 655
# player number 470 out of 655
# player number 471 out of 655
# player number 260 out of 655
# player number 473 out of 655
# player number 423 out of 655
# player number 216 out of 655
# player number 476 out of 655
# player number 37 out of 655
# player number 478 out of 655
# player number 289 out of 655
# player number 19 out of 655
# player number 292 out of 655
# player number 482 out of 655
# player number 483 out of 655
# player number 484 out of 655
# player number 485 out of 655
# player number 486 out of 655
# player number 487 out of 655
# player number 488 out of 655
# player number 489 out of 655
# player number 490 out of 655
# player number 491 out of 655
# player number 492 out of 655
# player number 493 out of 655
# player number 494 out of 655
# player number 495 out of 655
# player number 496 out of 655
# player number 497 out of 655
# player number 35 out of 655
# player number 499 out of 655
# player number 179 out of 655
# player number 308 out of 655
# player number 502 out of 655
# player number 503 out of 655
# player number 504 out of 655
# player number 505 out of 655
# player number 506 out of 655
# player number 507 out of 655
# player number 508 out of 655
# player number 509 out of 655
# player number 510 out of 655
# player number 511 out of 655
# player number 512 out of 655
# player number 320 out of 655
# player number 321 out of 655
# player number 515 out of 655
# player number 324 out of 655
# player number 517 out of 655
# player number 325 out of 655
# player number 519 out of 655
# player number 328 out of 655
# player number 521 out of 655
# player number 522 out of 655
# player number 523 out of 655
# player number 524 out of 655
# player number 525 out of 655
# player number 526 out of 655
# player number 527 out of 655
# player number 528 out of 655
# player number 529 out of 655
# player number 126 out of 655
# player number 238 out of 655
# player number 532 out of 655
# player number 533 out of 655
# player number 534 out of 655
# player number 535 out of 655
# player number 128 out of 655
# player number 445 out of 655
# player number 538 out of 655
# player number 539 out of 655
# player number 540 out of 655
# player number 541 out of 655
# player number 542 out of 655
# player number 61 out of 655
# player number 544 out of 655
# player number 545 out of 655
# player number 248 out of 655
# player number 547 out of 655
# player number 226 out of 655
# player number 549 out of 655
# player number 50 out of 655
# player number 551 out of 655
# player number 552 out of 655
# player number 553 out of 655
# player number 554 out of 655
# player number 555 out of 655
# player number 556 out of 655
# player number 557 out of 655
# player number 558 out of 655
# player number 535 out of 655
# player number 560 out of 655
# player number 561 out of 655
# player number 562 out of 655
# player number 246 out of 655
# player number 564 out of 655
# player number 565 out of 655
# player number 566 out of 655
# player number 567 out of 655
# player number 568 out of 655
# player number 457 out of 655
# player number 570 out of 655
# player number 571 out of 655
# player number 48 out of 655
# player number 573 out of 655
# player number 142 out of 655
# player number 575 out of 655
# player number 576 out of 655
# player number 441 out of 655
# player number 578 out of 655
# player number 579 out of 655
# player number 580 out of 655
# player number 581 out of 655
# player number 582 out of 655
# player number 583 out of 655
# player number 584 out of 655
# player number 585 out of 655
# player number 57 out of 655
# player number 326 out of 655
# player number 90 out of 655
# player number 589 out of 655
# player number 590 out of 655
# player number 591 out of 655
# player number 592 out of 655
# player number 593 out of 655
# player number 594 out of 655
# player number 595 out of 655
# player number 596 out of 655
# player number 597 out of 655
# player number 598 out of 655
# player number 599 out of 655
# player number 600 out of 655
# player number 601 out of 655
# player number 92 out of 655
# player number 603 out of 655
# player number 604 out of 655
# player number 605 out of 655
# player number 606 out of 655
# player number 607 out of 655
# player number 608 out of 655
# player number 609 out of 655
# player number 610 out of 655
# player number 611 out of 655
# player number 612 out of 655
# player number 613 out of 655
# player number 614 out of 655
# player number 615 out of 655
# player number 616 out of 655
# player number 396 out of 655
# player number 120 out of 655
# player number 619 out of 655
# player number 528 out of 655
# player number 621 out of 655
# player number 622 out of 655
# player number 127 out of 655
# player number 624 out of 655
# player number 540 out of 655
# player number 626 out of 655
# player number 627 out of 655
# player number 628 out of 655
# player number 629 out of 655
# player number 630 out of 655
# player number 631 out of 655
# player number 182 out of 655
# player number 431 out of 655
# player number 432 out of 655
# player number 635 out of 655
# player number 433 out of 655
# player number 637 out of 655
# player number 638 out of 655
# player number 639 out of 655
# player number 640 out of 655
# player number 78 out of 655
# player number 642 out of 655
# player number 643 out of 655
# player number 470 out of 655
# player number 579 out of 655
# player number 442 out of 655
# player number 647 out of 655
# player number 648 out of 655
# player number 82 out of 655
# player number 448 out of 655
# player number 651 out of 655
# player number 652 out of 655
# player number 653 out of 655
# player number 654 out of 655
# player number 655 out of 655
